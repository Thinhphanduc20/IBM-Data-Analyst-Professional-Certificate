# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data from GitHub Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'message': 'success', 'people': [{'craft': 'ISS', 'name': 'Mark Vande Hei'}, {'craft': 'ISS', 'name': 'Pyotr Dubrov'}, {'craft': 'ISS', 'name': 'Anton Shkaplerov'}, {'craft': 'Shenzhou 13', 'name': 'Zhai Zhigang'}, {'craft': 'Shenzhou 13', 'name': 'Wang Yaping'}, {'craft': 'Shenzhou 13', 'name': 'Ye Guangfu'}, {'craft': 'ISS', 'name': 'Raja Chari'}, {'craft': 'ISS', 'name': 'Tom Marshburn'}, {'craft': 'ISS', 'name': 'Kayla Barron'}, {'craft': 'ISS', 'name': 'Matthias Maurer'}, {'craft': 'ISS', 'name': 'Alexander Misurkin'}, {'craft': 'ISS', 'name': 'Yusaku Maezawa'}, {'craft': 'ISS', 'name': 'Yozo Hirano'}], 'number': 13}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 13

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 13 astronauts on ISS
# And their names are :
# Mark Vande Hei
# Pyotr Dubrov
# Anton Shkaplerov
# Zhai Zhigang
# Wang Yaping
# Ye Guangfu
# Raja Chari
# Tom Marshburn
# Kayla Barron
# Matthias Maurer
# Alexander Misurkin
# Yusaku Maezawa
# Yozo Hirano

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using GitHub Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
#Import required libraries
import requests
import json
import pandas as pd

# %%
baseurl = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/datasets/githubposting.json"
response = requests.get(baseurl)  
if response.ok:             
    data = response.json()    
data = pd.DataFrame(data)
print(data.to_string())
# Out:
#        technology number of job posting
# 0            java                     1
# 1               C                    10
# 2              C#                     1
# 3             C++                     1
# 4            Java                     2
# 5      JavaScript                     4
# 6          Python                     1
# 7           Scala                     5
# 8          Oracle                     0
# 9      SQL Server                     1
# 10   MySQL Server                     0
# 11     PostgreSQL                     1
# 12        MongoDB                     0
# 13           java                     1
# 14              C                    20
# 15             C#                     2
# 16            C++                     3
# 17           Java                     2
# 18     JavaScript                     3
# 19         Python                     2
# 20          Scala                     7
# 21         Oracle                     0
# ...

# %% [markdown]
# Write a function to get the number of jobs for the given technology.

# %%
data.rename(columns={"A": "technology", "B": "number of job posting"},inplace=True)
data[(data['technology']!="technology") & (data['number of job posting']!='number of job posting')]
data[[ "number of job posting"]] = data[["number of job posting"]].astype(int) 
def get_number_of_jobs(technology):

    #your code goes here
    number_of_jobs = data.groupby('technology').sum().loc[technology,:][0]
         
    return technology,number_of_jobs
print(get_number_of_jobs('Python'))
# Out:
# ('Python', 51)

# %% [markdown]
# Call the function for Python and check if it is working.

# %%
print(get_number_of_jobs('Python',))
print(get_number_of_jobs('Java',))
# Out:
# ('Python', 51)
# ('Java', 83)

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all technologies for which you need to find the number of jobs postings.

# %%
#your code goes here
technology =('C','C#','C++','Java','JavaScript','Python','Scala','Oracle','SQL Server','MySQL Server','PostgreSQL','MongoDB')
technology
# Out:
# ('C',
#  'C#',
#  'C++',
#  'Java',
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Oracle',
#  'SQL Server',
#  'MySQL Server',
#  'PostgreSQL',
#  'MongoDB')

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_column',None)
pd.set_option('display.max_row',100)
pd.set_option('display.width',1200)
# !pip3 install openpyxl
from openpyxl import Workbook

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here
wb=Workbook()                       
ws=wb.active

# %% [markdown]
# Find the number of jobs postings for each of the technology in the above list.
# Write the technology name and the number of jobs postings into the excel spreadsheet.

# %%
#your code goes here    
tech_list = list()
for language in technology:
    jobs = get_number_of_jobs(language)
    tech_list.append(jobs)
    
ws.append(['Language', 'Job Postings'])
[ws.append(i) for i in tech_list]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# Save into an excel spreadsheet named 'github-job-postings.xlsx'.

# %%
#your code goes here
wb.save("github-job-postings.xlsx")

# %%
with open('github-job-postings.xlsx','w',newline='') as file:
    csvwriter = csv.writer(file)
    for row in language:
        csvwriter.writerow(row)
df = pd.read_csv('github-job-postings.xlsx')

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df1 = pd.read_excel('github-job-postings.csv')
df1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_1663/745262390.py in <module>
#       4 import numpy as np
#       5
# ----> 6 df1 = pd.read_excel('github-job-postings.csv')
#       7 df1.head()
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
plt.figure(figsize=(16,9))
plt.title("Number of Jobs @ Github")
sns.barplot(data=df.sort_values(by="Job Postings", ascending=False),x="Language",y="Job Postings")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/wsuser/ipykernel_1663/1461550255.py in <module>
#       1 plt.figure(figsize=(16,9))
#       2 plt.title("Number of Jobs @ Github")
# ----> 3 sns.barplot(data=df.sort_values(by="Job Postings", ascending=False),x="Language",y="Job Postings")
#       4 plt.show()
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
# ...

# %%
job_data.columns
# Out:
# Index(['Language', 'Job Postings'], dtype='object')

# %%
job_data.groupby("Language").count()
# Out:
#               Job Postings
# Language
# C                        1
# C#                       1
# C++                      1
# Java                     1
# JavaScript               1
# MongoDB                  1
# MySQL Server             1
# Oracle                   1
# PostgreSQL               1
# Python                   1
# SQL Server               1
# Scala                    1

# %%
job_data.groupby("Job Postings").count()
# Out:
#               Language
# Job Postings
# 7                    1
# 8                    1
# 14                   1
# 16                   1
# 17                   1
# 18                   1
# 24                   1
# 47                   1
# 51                   1
# 65                   1
# 83                   1
# 184                  1

# %%
y = pd.DataFrame(job_data.groupby("Language").count())
y.sort_values(by="Language", ascending=False)
# Out:
#               Job Postings
# Language
# Scala                    1
# SQL Server               1
# Python                   1
# PostgreSQL               1
# Oracle                   1
# MySQL Server             1
# MongoDB                  1
# JavaScript               1
# Java                     1
# C++                      1
# C#                       1
# C                        1

# %%
y.plot(kind='bar',stacked=False,figsize=(20, 10))
plt.title("Top 5 DATABASES FOR THE NEXT YEAR")
y.plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/wsuser/ipykernel_297/2981220590.py in <module>
#       1 y.plot(kind='bar',stacked=False,figsize=(20, 10))
#       2 plt.title("Top 5 DATABASES FOR THE NEXT YEAR")
# ----> 3 y.plot.show()
#
# AttributeError: 'PlotAccessor' object has no attribute 'show'

# %%
y = pd.DataFrame(job_data.groupby("Language").count())
y.sort_values(by="Job Postings", ascending=False)
y.plot(kind='bar',stacked=False,figsize=(20, 10))
plt.title("Top 5 DATABASES FOR THE NEXT YEAR")
y.plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/wsuser/ipykernel_297/981591190.py in <module>
#       3 y.plot(kind='bar',stacked=False,figsize=(20, 10))
#       4 plt.title("Top 5 DATABASES FOR THE NEXT YEAR")
# ----> 5 y.plot.show()
#
# AttributeError: 'PlotAccessor' object has no attribute 'show'

# %%
perfomance = [184,14,24,83,65,51,47,8,16,7,17,18]
dfs = ['C','C#','C++','Java','JavaScript','Python','Scala','Oracle','SQL', 'Server','MySQL','Servel','PostgreSQL','MongoDB']
tks= np.arange(len(dfs))
plt.figure(figsize=(24,7))
plt.bar(tks,perfomance, align='center',alpha=0.1)
plt.xticks(tks,dfs)
plt.xlabel('Language')
plt.ylabel('Job Postings')
plt.title('GITHUB JOB POSTINGS')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/wsuser/ipykernel_297/3100140344.py in <module>
#       3 tks= np.arange(len(dfs))
#       4 plt.figure(figsize=(24,7))
# ----> 5 plt.bar(tks,perfomance, align='center',alpha=0.1)
#       6 plt.xticks(tks,dfs)
#       7 plt.xlabel('Language')
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# Out:
#               Job Postings
# Language
# C                        1
# C#                       1
# C++                      1
# Java                     1
# JavaScript               1
# MongoDB                  1
# MySQL Server             1
# Oracle                   1
# PostgreSQL               1
# Python                   1
# SQL Server               1
# Scala                    1

# %%
df2.groupby("DatabaseDesireNextYear").count()

# %%
Job_Postings = [130801, 114383,113865,110981,101013,94082,92037,88726,84727,84793]
Language = ['C','C#','C++','Java','JavaScript','Python','Scala','Oracle','SQL', 'Server','MySQL','Servel','PostgreSQL','MongoDB']
plt.figure(figsize=(16,7))
plt.bar(tks, perfomance, align='center',alpha=0.5)
plt.xticks(tks,dfs)
plt.title('Programming Language')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/wsuser/ipykernel_297/797645764.py in <module>
#       2 Language = ['C','C#','C++','Java','JavaScript','Python','Scala','Oracle','SQL', 'Server','MySQL','Servel','PostgreSQL','MongoDB']
#       3 plt.figure(figsize=(16,7))
# ----> 4 plt.bar(tks, perfomance, align='center',alpha=0.5)
#       5 plt.xticks(tks,dfs)
#       6 plt.title('Programming Language')
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %%
technology =('C','C#','C++','Java','JavaScript','Python','Scala','Oracle','SQL Server','MySQL Server','PostgreSQL','MongoDB')
technology
# Out:
# ('C',
#  'C#',
#  'C++',
#  'Java',
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Oracle',
#  'SQL Server',
#  'MySQL Server',
#  'PostgreSQL',
#  'MongoDB')

# %%
wb2=Workbook()                        
ws2=wb2.active

# %%
for ch in technology :
    print(get_number_of_jobs(ch))
    ws2.append(get_number_of_jobs(ch))
# Out:
# ('C', 184)
# ('C#', 14)
# ('C++', 24)
# ('Java', 83)
# ('JavaScript', 65)
# ('Python', 51)
# ('Scala', 47)
# ('Oracle', 8)
# ('SQL Server', 16)
# ('MySQL Server', 7)
# ('PostgreSQL', 17)
# ('MongoDB', 18)

# %%
wb2.save('github-job-posting.xlsx')
import pandas as pd
print (df1)
# Out:
#                C  184
# 0             C#   14
# 1            C++   24
# 2           Java   83
# 3     JavaScript   65
# 4         Python   51
# 5          Scala   47
# 6         Oracle    8
# 7     SQL Server   16
# 8   MySQL Server    7
# 9     PostgreSQL   17
# 10       MongoDB   18

# %%
perfomance = [184,14,24,83,65,51,47,8,16,7,17,18]
dfs = ['C','C#','C++','Java','JavaScript','Python','Scala','Oracle','SQL', 'Server','MySQL','Servel','PostgreSQL','MongoDB']
tck = np.arange(len(dfs))
plt.figure(figsize=(16,7))
plt.bar(tck, performance, align='center', alpha=0.5)
plt.xticks(tck, dfs)
plt.title('Programing Language')
plt.show

performance = [12,10,10,10,7,6,6,5,4,3,2,1]
dfs = ['MySQL Server', 'SQL Server', 'PostgreSQL', 'JavaScript','MongoDB','Oracle','Python','Scala','Java','C++','C#','C']
tck = np.arange(len(dfs))
plt.figure(figsize=(16,7))
plt.bar(tck, performance, align='center', alpha=0.5)

plt.xticks(tck, dfs)
plt.title('Programing Language')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/wsuser/ipykernel_297/4052077248.py in <module>
#       3 tck = np.arange(len(dfs))
#       4 plt.figure(figsize=(16,7))
# ----> 5 plt.bar(tck, performance, align='center', alpha=0.5)
#       6 plt.xticks(tck, dfs)
#       7 plt.title('Programing Language')
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2021-6-25         | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
