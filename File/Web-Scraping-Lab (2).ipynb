# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Extract information from a given web site
# *   Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
#
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
data  = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(data,"html5lib")

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
#your code goes here
table = soup.find("table")
popular_language =[]
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    language = cols[2].getText() # store the value in column 3 as color_name
    salary = cols[4].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(language,salary))
    popular_lan=[language,salary]
    popular_language.append(popular_lan)
    
print(popular_language)
# Out:
# Created By--->Learning Difficulty
# Guido van Rossum--->Easy
# James Gosling--->Easy
# Robert Gentleman, Ross Ihaka--->Hard
# Netscape--->Easy
# Apple--->Easy
# Bjarne Stroustrup--->Hard
# Microsoft--->Hard
# Rasmus Lerdorf--->Easy
# Donald D. Chamberlin, Raymond F. Boyce.--->Easy
# Robert Griesemer, Ken Thompson, Rob Pike.--->Difficult
# [['Created By', 'Learning Difficulty'], ['Guido van Rossum', 'Easy'], ['James Gosling', 'Easy'], ['Robert Gentleman, Ross Ihaka', 'Hard'], ['Netscape', 'Easy'], ['Apple', 'Easy'], ['Bjarne Stroustrup', 'Hard'], ['Microsoft', 'Hard'], ['Rasmus Lerdorf', 'Easy'], ['Donald D. Chamberlin, Raymond F. Boyce.', 'Easy'], ['Robert Griesemer, Ken Thompson, Rob Pike.', 'Difficult']]

# %%
table = soup.find("table")
popular_language =[]

for row in table.find_all('tr'):
    cols= row.find_all('td')
    language= cols[1].getText()
    salary = cols[3].getText()
    print(("{}--->{}").format(language,salary))
    popular_lan=[language,salary]
    popular_language.append(popular_lan)
    
print(popular_language)
# Out:
# Language--->Average Annual Salary
# Python--->$114,383
# Java--->$101,013
# R--->$92,037
# Javascript--->$110,981
# Swift--->$130,801
# C++--->$113,865
# C#--->$88,726
# PHP--->$84,727
# SQL--->$84,793
# Go--->$94,082
# [['Language', 'Average Annual Salary'], ['Python', '$114,383'], ['Java', '$101,013'], ['R', '$92,037'], ['Javascript', '$110,981'], ['Swift', '$130,801'], ['C++', '$113,865'], ['C#', '$88,726'], ['PHP', '$84,727'], ['SQL', '$84,793'], ['Go', '$94,082']]

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
# your code goes here
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('popular-languages.csv','w',newline='') as file:
    csvwriter = csv.writer(file)
    for row in popular_language:
        csvwriter.writerow(row)
df = pd.read_csv('popular-languages.csv')
df.head(50)
# Out:
#                                   Created By Learning Difficulty
# 0                           Guido van Rossum                Easy
# 1                              James Gosling                Easy
# 2               Robert Gentleman, Ross Ihaka                Hard
# 3                                   Netscape                Easy
# 4                                      Apple                Easy
# 5                          Bjarne Stroustrup                Hard
# 6                                  Microsoft                Hard
# 7                             Rasmus Lerdorf                Easy
# 8    Donald D. Chamberlin, Raymond F. Boyce.                Easy
# 9  Robert Griesemer, Ken Thompson, Rob Pike.           Difficult

# %%
perfomance = [130801, 114383,113865,110981,101013,94082,92037,88726,84727,84793]
dfs = ['Swift','Python','JAVA','C++','JavaScript','GO','R','C#','SQL','PHP']
tks= np.arange(len(dfs))
plt.figure(figsize=(16,7))
plt.bar(tks, perfomance, align='center',alpha=0.5)
plt.xticks(tks,dfs)
plt.xlabel('Language')
plt.ylabel('annual average salary')
plt.title('POPULAR PROGRAMMING LANGUAGES')
plt.show()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01).
